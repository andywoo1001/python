# 1171  2015-07-17  1300000  1311000  1278000  1305000  297200  1305000.00
# 1172  2015-07-20  1291000  1304000  1273000  1275000  128900  1275000.00
# 1173  2015-07-21  1275000  1277000  1247000  1263000  194000  1263000.00
# 1174  2015-07-22  1244000  1260000  1235000  1253000  268300  1253000.00
# 1175  2015-07-23  1244000  1253000  1234000  1234000  208900  1234000.00
# 1176  2015-07-24  1227000  1238000  1224000  1229000  196500  1229000.00
# 1177  2015-07-27  1229000  1247000  1228000  1230000  243000  1230000.00
# 1178  2015-07-28  1224000  1251000  1219000  1230000  267600  1230000.00
# 1179  2015-07-29  1250000  1275000  1231000  1263000  274600  1263000.00
#
#                MA240          DIFF
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
# 4                NaN           NaN
# 5                NaN           NaN
# 6                NaN           NaN
# 7                NaN           NaN
# 8                NaN           NaN
# 9                NaN           NaN
# 10               NaN           NaN
# 11               NaN           NaN
# 12               NaN           NaN
# 13               NaN           NaN
# 14               NaN           NaN
# 15               NaN           NaN
# 16               NaN           NaN
# 17               NaN           NaN
# 18               NaN           NaN
# 19               NaN           NaN
# 20               NaN           NaN
# 21               NaN           NaN
# 22               NaN           NaN
# 23               NaN           NaN
# 24               NaN           NaN
# 25               NaN           NaN
# 26               NaN           NaN
# 27               NaN           NaN
# 28               NaN           NaN
# 29               NaN           NaN
# ...              ...           ...
# 1150  1299120.836083 -34120.836083
# 1151  1298880.711875 -32880.711875
# 1152  1298662.021958 -17662.021958
# 1153  1298630.531542  22369.468458
# 1154  1298560.940167   3439.059833
# 1155  1298284.037083 -29284.037083
# 1156  1298044.634000 -20044.634000
# 1157  1297805.411208 -16805.411208
# 1158  1297397.037792 -29397.037792
# 1159  1297064.205250  -2064.205250
# 1160  1296961.581042   2038.418958
# 1161  1296939.225250 -28939.225250
# 1162  1296655.871875 -66655.871875
# 1163  1296418.291708 -56418.291708
# 1164  1296242.250000 -57242.250000
# 1165  1296215.607333 -31215.607333
# 1166  1296328.227500 -37328.227500
# 1167  1296387.882917 -30387.882917
# 1168  1296293.131292 -71293.131292
# 1169  1296248.259458 -61248.259458
# 1170  1296411.540667 -14411.540667
# 1171  1296670.655208   8329.344792
# 1172  1296849.942042 -21849.942042
# 1173  1296962.802583 -33962.802583
# 1174  1297005.250458 -44005.250458
# 1175  1297075.302500 -63075.302500
# 1176  1297075.242375 -68075.242375
# 1177  1297157.373750 -67157.373750
# 1178  1297264.144542 -67264.144542
# 1179  1297475.562792 -34475.562792
#
# [1180 rows x 9 columns]

# %% [markdown]
# ## Plot a live graph from a text file

# %%
fig = plt.figure()
chart = fig.add_subplot(1,1,1)

def animate(i):
    pullData = open('sample.txt', 'r').read()
    dataArray = pullData.split('\n')
    xar =[]
    yar =[]
    for eachLine in dataArray:
        if len(eachLine) > 1:
            x,y = eachLine.split(',')
            xar.append(int(x))
            yar.append(int(y))
    chart.clear()
    chart.plot(xar, yar)
ani = animation.FuncAnimation(fig, animate, interval = 1000)
plt.show()

# %% [markdown]
# ## Plot a live graph from CSV

# %%
fig = plt.figure()
chart = fig.add_subplot(1,1,1)
DB = pd.read_csv('005930.csv')

def animate(i):
    frame = 240 + i
    index = DB.index[:frame]
    Value = DB['Adj Close'][:frame]
    #MA30  =  DB['MA30'][:frame]
    MA240 =  DB['MA240'][:frame]
    chart.clear()
    chart.plot(index, Value, 'g')
    #chart.plot(index, MA30, 'r')
    chart.plot(index, MA240, 'b')
    
ani = animation.FuncAnimation(fig, animate, interval = 10)
plt.show()
